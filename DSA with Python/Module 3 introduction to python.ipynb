# %% [markdown]
# ![image](introToPy.png)

# %% [markdown]
# # 🐍 Module 3: Basics of Programming in Python
#
# **Duration:** 5h 3m
# **Total Lectures:** 19
#
# ## Introduction
#
# Python is a **high-level, general-purpose programming language** known for its simple syntax, readability, and powerful built-in features. For **Data Structures and Algorithms (DSA)**, Python provides a clean environment in which you can focus on **problem-solving, algorithmic thinking, and complexity analysis** rather than spending too much time on complicated syntax.
#
# This module builds the **core Python programming foundation required for DSA and coding interviews**. It starts with basic problem-solving concepts such as flowcharts, variables, data types, operators, and control flow, and gradually progresses toward functions, recursion, lists, strings, dictionaries, sets, and tuples.
#
# By the end of this module, you should be comfortable writing Python programs independently and using Python's built-in data structures to solve **basic to intermediate programming problems**.
#
# ---
#
# # 🎯 Learning Objectives
#
# By completing this module, you will be able to:
#
# * Understand how to represent a problem using **flowcharts**.
# * Work with **variables, references, and Python data types**.
# * Use different types of **operators** effectively.
# * Implement decision-making using **conditional statements**.
# * Use `for` and `while` loops to solve repetitive problems.
# * Control program execution using **jump statements**.
# * Develop logical thinking through **pattern-printing problems**.
# * Create reusable solutions using **functions**.
# * Understand and implement **recursion**.
# * Understand **variable scope** and Python's LEGB rule.
# * Work efficiently with **lists and 2D lists**.
# * Solve common **list-based coding problems**.
# * Use **slicing and list comprehensions**.
# * Work with **strings** and solve common string problems.
# * Use **dictionaries** for key-value mapping and frequency counting.
# * Use **sets** for unique elements and fast membership testing.
# * Understand and use **tuples** for fixed collections.
# * Analyze basic **time and space complexity**.
# * Build a strong foundation for advanced **DSA and coding interviews**.
#
# ---
#
# # 📚 Lecture 1: Flowcharts
#
# Before writing Python code, it is important to understand how to **break a problem into logical steps**.
#
# A flowchart provides a visual representation of the steps required to solve a problem.
#
# ### Topics Covered
#
# * What is a flowchart?
# * Why flowcharts are useful
# * Common flowchart symbols
# * Start and End
# * Input and Output
# * Processing
# * Decision-making
# * Flow of execution
# * Sequential logic
# * Conditional logic
# * Repetitive logic
# * Converting a problem into a flowchart
# * Converting a flowchart into Python code
#
# ### DSA Connection
#
# Flowcharts help develop **algorithmic thinking** before implementation.
#
# For example:
#
# ```text
# Start
#   ↓
# Input Number
#   ↓
# Is Number > 0?
#   ↓
#  ┌─────────────┐
# Yes           No
#  ↓             ↓
# Positive     Negative
#  └──────┬──────┘
#         ↓
#        End
# ```
#
# ---
#
# # 📦 Lecture 2: Variables and Data Types
#
# Variables are used to **store and reference data** in a Python program.
#
# ### Topics Covered
#
# * What is a variable?
# * Creating variables
# * Naming rules
# * Naming conventions
# * Dynamic typing
# * Multiple assignment
# * Constants by convention
# * Checking data types using `type()`
# * Type conversion
# * Numeric data types
# * Strings
# * Booleans
# * `None`
# * Mutable and immutable objects
#
# ### Important Data Types
#
# | Type    | Example     | Common DSA Use                  |
# | ------- | ----------- | ------------------------------- |
# | `int`   | `10`        | Counters, indexes, calculations |
# | `float` | `3.14`      | Decimal calculations            |
# | `str`   | `"Python"`  | String problems                 |
# | `bool`  | `True`      | Conditions                      |
# | `list`  | `[1, 2, 3]` | Arrays/sequences                |
# | `tuple` | `(1, 2, 3)` | Fixed collections               |
# | `set`   | `{1, 2, 3}` | Unique values                   |
# | `dict`  | `{"a": 1}`  | Hash maps                       |
#
# ### Example
#
# ```python
# age = 21
# name = "Alice"
# score = 95.5
# is_student = True
#
# print(type(age))
# print(type(name))
# print(type(score))
# print(type(is_student))
# ```
#
# ---
#
# # 🔗 Lecture 3: References and Operators
#
# Python variables work as **references to objects** rather than simply being fixed memory containers.
#
# Understanding references becomes important when working with **mutable data structures**, especially lists and dictionaries.
#
# ### References
#
# You will learn:
#
# * Variables and objects
# * Object references
# * `id()`
# * Object identity
# * `is` vs `==`
# * Mutable objects
# * Immutable objects
# * Assignment and references
# * Aliasing
# * Copying objects
#
# Example:
#
# ```python
# a = [1, 2, 3]
# b = a
#
# b.append(4)
#
# print(a)
# print(b)
# ```
#
# Both variables refer to the same list.
#
# ### Operators
#
# You will learn:
#
# * Arithmetic operators
# * Comparison operators
# * Logical operators
# * Assignment operators
# * Bitwise operators
# * Membership operators
# * Identity operators
# * Operator precedence
#
# Example:
#
# ```python
# a = 10
# b = 3
#
# print(a + b)
# print(a > b)
# print(a == b)
# print(a % b)
# print(a in [5, 10, 15])
# ```
#
# ### DSA Connection
#
# Operators such as `%`, `//`, comparison operators, and bitwise operators are frequently used in coding problems.
#
# ---
#
# # 🔀 Lecture 4: Conditional Statements
#
# Conditional statements allow a program to **make decisions based on conditions**.
#
# ### Topics Covered
#
# * `if`
# * `if-else`
# * `if-elif-else`
# * Nested conditions
# * Multiple conditions
# * Logical operators
# * Comparison operators
# * Conditional expressions
# * Nested decision-making
#
# ### Example
#
# ```python
# marks = 75
#
# if marks >= 90:
#     print("Excellent")
# elif marks >= 60:
#     print("Good")
# else:
#     print("Needs Improvement")
# ```
#
# ### DSA Connection
#
# Conditional logic is used in almost every algorithm, including:
#
# * Searching
# * Sorting
# * Array problems
# * String problems
# * Recursion
# * Trees
# * Graphs
# * Dynamic programming
#
# ---
#
# # 🔁 Lecture 5: Loops
#
# Loops allow us to **repeat a block of code** efficiently.
#
# ### Topics Covered
#
# * `for` loop
# * `while` loop
# * `range()`
# * Nested loops
# * Iterating through sequences
# * Loop conditions
# * Loop counters
# * Infinite loops
# * Common loop patterns
#
# ### Example
#
# ```python
# for i in range(1, 6):
#     print(i)
# ```
#
# ### Nested Loops
#
# ```python
# for i in range(3):
#     for j in range(3):
#         print(i, j)
# ```
#
# ### DSA Connection
#
# Loops are fundamental to:
#
# * Array traversal
# * Searching
# * Sorting
# * Matrix problems
# * Pattern problems
# * Frequency counting
# * Two-pointer techniques
# * Sliding-window techniques
#
# You will also begin connecting loops with **time complexity**.
#
# For example:
#
# ```python
# for i in range(n):
#     print(i)
# ```
#
# Generally has:
#
# ```text
# Time Complexity: O(n)
# ```
#
# ---
#
# # ⏭️ Lecture 6: Jump Statements
#
# Jump statements allow you to **change the normal flow of program execution**.
#
# ### Topics Covered
#
# * `break`
# * `continue`
# * `pass`
# * `return`
# * When to use each statement
# * Avoiding unnecessary control-flow complexity
#
# ### Example
#
# ```python
# for number in range(1, 10):
#
#     if number == 5:
#         break
#
#     print(number)
# ```
#
# Output:
#
# ```text
# 1
# 2
# 3
# 4
# ```
#
# ### DSA Connection
#
# Jump statements are useful when:
#
# * A search is successful and you want to stop.
# * A particular element should be skipped.
# * A function has found its answer and should return immediately.
#
# ---
#
# # ⭐ Lecture 7: Pattern Printing
#
# Pattern printing is an important beginner-level problem-solving exercise.
#
# Although patterns may appear simple, they help develop the ability to translate a visual requirement into **nested loops and logical conditions**.
#
# ### Topics Covered
#
# * Basic star patterns
# * Number patterns
# * Character patterns
# * Increasing patterns
# * Decreasing patterns
# * Pyramid patterns
# * Inverted pyramids
# * Spaces and alignment
# * Nested-loop logic
#
# Example:
#
# ```text
# *
# **
# ***
# ****
# *****
# ```
#
# Python implementation:
#
# ```python
# for i in range(1, 6):
#     print("*" * i)
# ```
#
# ### DSA Connection
#
# Pattern problems strengthen:
#
# * Loop understanding
# * Nested-loop logic
# * Index manipulation
# * Condition handling
# * Problem decomposition
#
# ---
#
# # 🧩 Lecture 8: Functions
#
# Functions allow us to divide a large problem into **small, reusable components**.
#
# ### Topics Covered
#
# * What is a function?
# * Defining functions
# * Calling functions
# * Parameters
# * Arguments
# * Return values
# * Default arguments
# * Keyword arguments
# * Positional arguments
# * Multiple return values
# * Function composition
# * Reusable code
#
# ### Example
#
# ```python
# def add(a, b):
#     return a + b
#
# result = add(10, 20)
#
# print(result)
# ```
#
# ### DSA Connection
#
# Most DSA solutions are written as functions.
#
# For example:
#
# ```python
# def find_max(numbers):
#     maximum = numbers[0]
#
#     for number in numbers:
#         if number > maximum:
#             maximum = number
#
#     return maximum
# ```
#
# Functions make algorithms **modular, reusable, and easier to test**.
#
# ---
#
# # 🔄 Lecture 9: Recursion
#
# **Recursion** occurs when a function calls itself to solve a smaller version of the same problem.
#
# ### Topics Covered
#
# * What is recursion?
# * Recursive function
# * Base case
# * Recursive case
# * Recursive call
# * Call stack
# * Tracing recursive execution
# * Factorial
# * Fibonacci
# * Sum of numbers
# * Recursive searching
# * Recursion vs iteration
#
# ### Example
#
# ```python
# def factorial(n):
#
#     if n == 0:
#         return 1
#
#     return n * factorial(n - 1)
# ```
#
# ### DSA Connection
#
# Recursion is essential for understanding:
#
# * Tree traversal
# * Graph traversal
# * Backtracking
# * Divide and conquer
# * Merge sort
# * Quick sort
# * Dynamic programming
#
# ---
#
# # 🌍 Lecture 10: Scope
#
# **Scope** determines where a variable can be accessed in a Python program.
#
# ### Topics Covered
#
# * Local scope
# * Global scope
# * Enclosing scope
# * Built-in scope
# * LEGB rule
# * `global`
# * `nonlocal`
# * Scope inside functions
# * Common scope-related mistakes
#
# Example:
#
# ```python
# x = 10
#
# def show():
#     x = 20
#     print(x)
#
# show()
#
# print(x)
# ```
#
# Understanding scope is particularly important when working with **functions, recursion, nested functions, and callbacks**.
#
# ---
#
# # 📋 Lecture 11: List
#
# A **list** is an ordered and mutable collection in Python.
#
# ```python
# numbers = [10, 20, 30, 40, 50]
# ```
#
# ### Topics Covered
#
# * Creating lists
# * Indexing
# * Negative indexing
# * Updating elements
# * Adding elements
# * Removing elements
# * `append()`
# * `insert()`
# * `extend()`
# * `remove()`
# * `pop()`
# * `clear()`
# * `sort()`
# * `reverse()`
# * Iterating through lists
# * Nested lists
# * List time complexity
#
# ### DSA Connection
#
# Python lists are heavily used to represent **arrays and dynamic sequences**.
#
# ---
#
# # 🧠 Lecture 12: List Questions
#
# This lecture focuses on applying list concepts to **problem-solving and interview questions**.
#
# ### Problems Include
#
# * Find the largest element
# * Find the smallest element
# * Find the sum of elements
# * Calculate the average
# * Search for an element
# * Count occurrences
# * Reverse a list
# * Find the second-largest element
# * Check whether a list is sorted
# * Remove duplicates
# * Find missing values
# * Find common elements
# * Rotate a list
# * Separate even and odd numbers
#
# ### Interview Focus
#
# For each problem, learn to identify:
#
# ```text
# Input
#   ↓
# Expected Output
#   ↓
# Approach
#   ↓
# Data Structure
#   ↓
# Algorithm
#   ↓
# Implementation
#   ↓
# Time Complexity
#   ↓
# Space Complexity
# ```
#
# ---
#
# # ✂️ Lecture 13: Slicing and List Comprehension
#
# Python provides powerful techniques for working with sequences.
#
# ## Slicing
#
# ```python
# numbers = [10, 20, 30, 40, 50]
#
# print(numbers[1:4])
# ```
#
# Output:
#
# ```text
# [20, 30, 40]
# ```
#
# ### Topics Covered
#
# * Start index
# * Stop index
# * Step
# * Negative indexing
# * Reverse slicing
# * String slicing
# * List slicing
#
# General syntax:
#
# ```python
# sequence[start:stop:step]
# ```
#
# ## List Comprehension
#
# List comprehensions provide a concise way to create lists.
#
# ```python
# squares = [x * x for x in range(1, 6)]
#
# print(squares)
# ```
#
# Output:
#
# ```text
# [1, 4, 9, 16, 25]
# ```
#
# You will learn:
#
# * Basic list comprehensions
# * Conditional comprehensions
# * Nested comprehensions
# * When to use comprehensions
# * When traditional loops are more readable
#
# ---
#
# # 🧮 Lecture 14: 2D Lists
#
# A **2D list** is a list containing other lists and can be used to represent **matrices, tables, grids, and game boards**.
#
# Example:
#
# ```python
# matrix = [
#     [1, 2, 3],
#     [4, 5, 6],
#     [7, 8, 9]
# ]
# ```
#
# ### Topics Covered
#
# * Creating 2D lists
# * Accessing rows
# * Accessing columns
# * Updating elements
# * Nested loops
# * Matrix traversal
# * Row-wise traversal
# * Column-wise traversal
# * Basic matrix operations
# * Grid-based problems
#
# ### DSA Connection
#
# 2D lists provide the foundation for:
#
# * Matrix problems
# * Grid problems
# * Image-like data
# * Game boards
# * Dynamic programming tables
# * Graph representations
#
# ---
#
# # 🔤 Lecture 15: Strings
#
# A **string** is a sequence of characters.
#
# ```python
# text = "Python"
# ```
#
# ### Topics Covered
#
# * Creating strings
# * Indexing
# * Negative indexing
# * Slicing
# * String traversal
# * String concatenation
# * String comparison
# * String methods
# * `split()`
# * `join()`
# * `replace()`
# * `find()`
# * `count()`
# * `lower()`
# * `upper()`
# * String immutability
#
# ### DSA Connection
#
# Strings are one of the most common topics in coding interviews.
#
# They are used in problems involving:
#
# * Characters
# * Substrings
# * Palindromes
# * Anagrams
# * Frequency counting
# * Pattern matching
#
# ---
#
# # 🧩 Lecture 16: Questions on Strings
#
# This lecture focuses on solving common **string-based coding problems**.
#
# ### Problems Include
#
# * Reverse a string
# * Check whether a string is a palindrome
# * Count characters
# * Count vowels and consonants
# * Find duplicate characters
# * Find the first non-repeating character
# * Check whether two strings are anagrams
# * Remove duplicate characters
# * Count word frequency
# * Find the longest word
# * Search for a substring
# * Reverse words in a sentence
#
# Example:
#
# ```python
# text = "level"
#
# if text == text[::-1]:
#     print("Palindrome")
# else:
#     print("Not a palindrome")
# ```
#
# ### Interview Focus
#
# The goal is not simply to memorize solutions but to understand **how to approach string problems systematically**.
#
# ---
#
# # 📖 Lecture 17: Dictionary
#
# A **dictionary** stores data using **key-value pairs**.
#
# ```python
# student = {
#     "name": "Alice",
#     "age": 21,
#     "course": "Computer Science"
# }
# ```
#
# ### Topics Covered
#
# * Creating dictionaries
# * Accessing values
# * Adding key-value pairs
# * Updating values
# * Removing entries
# * `keys()`
# * `values()`
# * `items()`
# * `get()`
# * Iterating over dictionaries
# * Checking whether a key exists
# * Nested dictionaries
# * Dictionary time complexity
#
# ### DSA Connection
#
# Dictionaries are extremely important for **hashing-based problems**.
#
# Common applications include:
#
# * Frequency counting
# * Fast lookups
# * Duplicate detection
# * Caching
# * Mapping relationships
# * Counting characters
# * Counting array elements
#
# Example:
#
# ```python
# numbers = [1, 2, 2, 3, 3, 3]
#
# frequency = {}
#
# for number in numbers:
#     frequency[number] = frequency.get(number, 0) + 1
#
# print(frequency)
# ```
#
# Output:
#
# ```text
# {1: 1, 2: 2, 3: 3}
# ```
#
# ---
#
# # 🎯 Lecture 18: Sets
#
# A **set** is an unordered collection of **unique elements**.
#
# ```python
# numbers = {10, 20, 30, 40}
# ```
#
# ### Topics Covered
#
# * Creating sets
# * Adding elements
# * Removing elements
# * Membership testing
# * Removing duplicates
# * Union
# * Intersection
# * Difference
# * Symmetric difference
# * Set methods
# * Set time complexity
#
# ### DSA Connection
#
# Sets are useful for:
#
# * Duplicate detection
# * Removing duplicate values
# * Fast membership testing
# * Finding common elements
# * Comparing collections
# * Hashing-based problems
#
# Example:
#
# ```python
# numbers = [1, 2, 2, 3, 4, 4]
#
# unique_numbers = set(numbers)
#
# print(unique_numbers)
# ```
#
# ---
#
# # 🧩 Lecture 19: Tuples
#
# A **tuple** is an **ordered and immutable** collection in Python.
#
# ```python
# coordinates = (10, 20)
# ```
#
# ### Topics Covered
#
# * Creating tuples
# * Indexing
# * Slicing
# * Tuple unpacking
# * Tuple packing
# * Multiple return values
# * Nested tuples
# * Tuple immutability
# * Tuple vs list
# * Tuple as dictionary keys
# * Tuple time complexity
#
# ### DSA Connection
#
# Tuples are useful when working with **fixed groups of values**.
#
# Common examples include:
#
# * Coordinates
# * Graph edges
# * Database records
# * Function return values
# * Dictionary keys
# * Fixed configuration data
#
# Example:
#
# ```python
# point = (10, 20)
#
# x, y = point
#
# print(x)
# print(y)
# ```
#
# ---
#
# # 💼 Interview Preparation Throughout the Module
#
# Every major topic in this module should be connected to **DSA and technical interviews**.
#
# You will learn to think about:
#
# ### Correctness
#
# Does the solution produce the expected output for all valid inputs?
#
# ### Time Complexity
#
# How does the running time grow as the input size increases?
#
# Common complexities:
#
# ```text
# O(1)       Constant
# O(log n)   Logarithmic
# O(n)       Linear
# O(n log n) Linearithmic
# O(n²)      Quadratic
# O(2ⁿ)      Exponential
# ```
#
# ### Space Complexity
#
# How much additional memory does the solution require?
#
# ### Edge Cases
#
# Always consider situations such as:
#
# * Empty input
# * One element
# * Duplicate values
# * Negative numbers
# * Very large input
# * Already sorted data
# * Repeated characters
# * Missing values
#
# ---
#
# # 🛠️ Practical Problem-Solving Workflow
#
# For every coding problem, follow this process:
#
# ```text
# Understand the Problem
#         ↓
# Identify Input and Output
#         ↓
# Work Through an Example
#         ↓
# Identify the Pattern
#         ↓
# Choose a Data Structure
#         ↓
# Design the Algorithm
#         ↓
# Write Python Code
#         ↓
# Test the Solution
#         ↓
# Check Edge Cases
#         ↓
# Analyze Time Complexity
#         ↓
# Analyze Space Complexity
#         ↓
# Optimize if Necessary
# ```
#
# This approach is more important for DSA than simply memorizing Python syntax.
#
# ---
#
# # 🚀 Module Outcome
#
# After completing these **19 lectures**, you will have a solid Python foundation for beginning dedicated DSA study.
#
# You will progress from:
#
# ```text
# Programming Logic
#        ↓
# Python Fundamentals
#        ↓
# Control Flow
#        ↓
# Functions & Recursion
#        ↓
# Lists
#        ↓
# List Problem Solving
#        ↓
# 2D Lists
#        ↓
# Strings
#        ↓
# String Problem Solving
#        ↓
# Dictionaries
#        ↓
# Sets
#        ↓
# Tuples
#        ↓
# DSA Problem Solving
# ```
#
# ## 💡 Key Takeaway
#
# > **This module is the bridge between learning Python and solving DSA problems with Python.**
# >
# > By mastering **flowcharts, variables, operators, conditions, loops, functions, recursion, scope, lists, strings, dictionaries, sets, and tuples**, you will have the programming foundation needed to move confidently into **searching, sorting, stacks, queues, linked lists, trees, graphs, greedy algorithms, dynamic programming, and coding-interview problems**.

# %% [markdown]
# ###
# 1. Flowcharts
